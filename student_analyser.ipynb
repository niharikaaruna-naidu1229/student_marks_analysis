# %%
import pandas as pd

data = pd.read_excel("C:\\Users\\NIHARIKA\\Documents\\Book1.xlsx")
print("Average Marks:")
print(data.mean(numeric_only=True))

print("\nTop Student:")
data["Total"] = data[["Hindi","English","Maths","Physics","Social"]].sum(axis=1)
print(data.loc[data["Total"].idxmax()])
# Out:
# Average Marks:
# sno        13.500000
# Hindi      86.833333
# English    82.000000
# Maths      83.166667
# Physics    80.166667
# Social     86.333333
# dtype: float64
#
# Top Student:
# sno               13
# name       Harshitha
# Hindi             95
# English           99
# Maths             97
# Physics           94
# Social            92
# Total            477
# Name: 2, dtype: object
